# %% [markdown]
# #1. 함수와 합성함수 (Function & Composition)
#
# - 개념 요약: 함수는 입력값에 대응하는 출력값을 만드는 규칙
#
# - 합성함수는 함수가 또 다른 함수의 입력으로 들어갈 때 만들어집니다.

# %%
#1단계(기초) - 함수와 합성함수 시각화
import numpy as np
import matplotlib.pyplot as plt

f = lambda x: 2*x + 1
g = lambda x: x**2
x = np.linspace(-3, 3, 200)

plt.figure()
plt.plot(x, f(x), label='f(x)=2x+1')
plt.plot(x, g(x), label='g(x)=x^2')
plt.plot(x, g(f(x)), '--', label='g(f(x))')
plt.legend(); plt.grid(True); plt.title('Function Composition')
plt.show()

# %% [markdown]
# 함수 $f(x)=2x+1$과 $g(x)=x^2$를 각각 그리고, 두 함수를 합성한 $g(f(x))$의 그래프를 함께 시각화 해보자.

# %%
import numpy as np
import matplotlib.pyplot as plt

f = lambda x: 2*x + 1
g = lambda x: x**2
x = np.linspace(-3, 3, 200)

fig, axes = plt.subplots(1, 3, figsize=(12, 4))

# 1번째: f(x)
axes[0].plot(x, f(x))
axes[0].set_title('f(x) = 2x + 1')
axes[0].grid(True)

# 2번째: g(x)
axes[1].plot(x, g(x))
axes[1].set_title('g(x) = x²')
axes[1].grid(True)

# 3번째: g(f(x))
axes[2].plot(x, g(f(x)), '--')
axes[2].set_title('g(f(x)) = (2x+1)²')
axes[2].grid(True)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

start = time.time()
x = np.linspace(-3, 3, 200)
funcs = [
    ('f(x)=2x+1', lambda x: 2*x + 1),
    ('g(x)=x²', lambda x: x**2),
    ('g(f(x))=(2x+1)²', lambda x: (2*x+1)**2)
]

for title, func in funcs:
    plt.figure(figsize=(4, 3))
    plt.plot(x, func(x))
    plt.title(title)
    plt.grid(True)
    plt.show()
print(f"{time.time() - start:4f} sec")
# Out:
# 0.273421 sec

# %% [markdown]
# - 함수의 개수가 늘어나면 subplot도 자동으로 늘어나는 코드

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-3, 3, 200)
funcs = [
    ('f(x)=2x+1', lambda x: 2*x + 1),
    ('g(x)=x²', lambda x: x**2),
    ('g(f(x))=(2x+1)²', lambda x: (2*x+1)**2)
]

fig, axes = plt.subplots(1, len(funcs), figsize=(12, 4))
for ax, (label, func) in zip(axes, funcs):
    ax.plot(x, func(x))
    ax.set_title(label)
    ax.grid(True)

plt.tight_layout()
plt.show()

# %%
#2단계(중급) - 입력에 따라 함수가 변할 때 / 함수의 계수 변화 -> 시각화
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-3, 3, 300)

# Try different slopes (a)
for a in [0.5, 1, 2]:
    f = lambda x: a*x + 1
    plt.plot(x, f(x), label=f'a={a}')

plt.legend(); plt.grid(True)
plt.title('Effect of slope a on f(x)=a*x+1')
plt.xlabel('x'); plt.ylabel('f(x)')
plt.show()

# %%
#3단계(응용) - 합성 순서 바꿔보기
import numpy as np
import matplotlib.pyplot as plt

f = lambda x: 2*x + 1
g = lambda x: x**2
x = np.linspace(-3, 3, 300)

plt.figure()
plt.plot(x, g(f(x)), '--', label='g(f(x))')
plt.plot(x, f(g(x)), '-.', label='f(g(x))')
plt.legend(); plt.grid(True)
plt.title('Compare g(f(x)) and f(g(x))')
plt.show()

# %%
#4단계(확장)
import numpy as np
import matplotlib.pyplot as plt

f = lambda x: np.sin(x)
g = lambda x: x**2
x = np.linspace(-3, 3, 300)

plt.figure()
plt.plot(x, g(f(x)), '--', label='g(f(x))')
plt.plot(x, f(g(x)), '-.', label='f(g(x))')
plt.legend(); plt.grid(True)
plt.title('Compare g(f(x)) and f(g(x))')
plt.show()

# %% [markdown]
# #2. 로그와 지수함수 (Log & Exponential)
# - 지수함수는 급격히 증가합니다.
# - 로그함수는 서서히 증가합니다.
# - 데이터 스케일이 너무 클 때 로그변환을 하면 분포를 보기 좋게 만들 수 있습니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0.1, 5, 200)
plt.figure()
plt.plot(x, np.exp(x), label='exp(x)')
plt.plot(x, np.log(x), label='log(x)')
plt.legend(); plt.grid(True); plt.title('Exponential vs Logarithm')
plt.show()

# %%
#2단계(중급) - 축 스케일과 성질 이해
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0.1, 5, 200)

# (A) 같은 데이터, y축 로그 스케일
plt.figure()
plt.plot(x, np.exp(x), label='exp(x)')
plt.plot(x, np.log(x), label='log(x)')
plt.yscale('log')
plt.legend(); plt.grid(True); plt.title('Log-scale on Y (semilogy)')
plt.show()

# (B) x축과 y축을 각각 로그로 바꾸면 모양이 어떻게 달라지는지
plt.figure()
plt.plot(x, np.log(x), label='log(x)')
plt.xscale('log'); plt.yscale('linear')
plt.legend(); plt.grid(True); plt.title('Log-scale on X (semilogx)')
plt.show()

# %%
# 3단계(응용) - 데이터 분포, 변환 활용
## 정규분포는 대칭이고, 로그변환하면 오히려 치우친다.
## Skewness(왜도): 정규분포에서 0에 가까움.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew

# (A) 정규분포: 원래 분포 vs 로그변환 후 분포
rng = np.random.default_rng(0)  # 난수 생성기
data = rng.normal(loc=0.0, scale=1.0, size=2000)  # 평균 0, 표준편차 1인 정규분포

# 원래(정규분포): 대칭적 형태
plt.figure()
plt.hist(data, bins=50, color='skyblue', edgecolor='black')
plt.grid(True)
plt.title('Original Normal Distribution (symmetric)')
plt.xlabel('Value'); plt.ylabel('Frequency')
plt.show()

# 왜도(Skewness) 계산
sk = skew(data)
print("Skewness (normal):", sk)

# 로그변환은 음수 불가능하므로 평행이동 후 적용
data_shifted = data - data.min() + 1e-6  # 전체를 양수로 이동
data_log = np.log(data_shifted)

# 로그변환 후: 오른쪽 꼬리가 긴 형태로 변형됨
plt.figure()
plt.hist(data_log, bins=50, color='salmon', edgecolor='black')
plt.grid(True)
plt.title('After log transform: now skewed (right tail)')
plt.xlabel('log(Value)'); plt.ylabel('Frequency')
plt.show()

# 왜도 비교
print("Skewness after log transform:", skew(data_log))
# Out:
# Skewness (normal): -0.061887946444646846
# Skewness after log transform: -19.54125966062708

# %%
#3단계(응용) - 데이터 분포, 변환 활용
##로그변환은 치우친 분포를 다룰 때 유용
## 거듭제곱 관계는 로그-로그좌표에서 직선처럼 보임.
## Skewness(왜도): 정규분포에 의해, 얼마나 치우쳐 있는지를 보는 것.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew

# (A) 로그정규분포: 원래 분포 vs 로그변환 후 분포
rng = np.random.default_rng(0)        # 난수(random number) 생성기 초기화
np.random.seed(42)                    # 시드 고정 → 동일한 난수 재현 가능
data = rng.lognormal(mean=2.0, sigma=1.0, size=2000)  # 로그정규분포 샘플 생성

# 원래(로그정규) 분포: 오른쪽 꼬리가 긴(skewed) 형태
plt.figure()
plt.hist(data, bins=50, color='skyblue', edgecolor='black')
plt.grid(True)
plt.title('Skewed data (Lognormal distribution)')
plt.xlabel('Value'); plt.ylabel('Frequency')
plt.show()

# 왜도(Skewness) 계산
sk = skew(data)
print("Skewness (lognormal):", sk)

# 로그변환 후: log(data) → 보다 대칭적인(정규에 가까운) 형태로 변환
plt.figure()
plt.hist(np.log(data), bins=50, color='salmon', edgecolor='black')
plt.grid(True)
plt.title('After log transform: more symmetric (≈ Normal)')
plt.xlabel('log(Value)'); plt.ylabel('Frequency')
plt.show()

# 왜도 비교
print("Skewness after log transform:", skew(np.log(data)))
# Out:
# Skewness (lognormal): 3.617158231541673
# Skewness after log transform: -0.06188794644464688

# %% [markdown]
# #3.수열과 극한 (Sequence & Limit)
#
# - 반복되는 값이 일정한 수로 가까워지면 ‘수렴’, 끝없이 커지면 ‘발산’이라고 합니다.

# %%
#1단계(기초) - 수렴(수열이 일정한 값으로 가까워질때 "수렴(Converge)한다고 함.")
import numpy as np
import matplotlib.pyplot as plt

n = np.arange(1, 60)
a = 1 - 1/n
plt.plot(n, a, 'o-')
plt.axhline(1, linestyle='--')
plt.grid(True); plt.title('lim (1 - 1/n) = 1')
plt.show()

# %%
# 2단계= - 발산과 교대수열
## 발산(diverge): 수열이 한 값으로 모이지 않음.
## 절대값은 수렴하지만 부호가 교대되는 교대수열.

import numpy as np
import matplotlib.pyplot as plt

n = np.arange(1, 20)
b = (-1)**n

plt.figure()
plt.stem(n, b, basefmt=" ")
plt.grid(True)
plt.title('Step 2 (Intermediate): Divergent sequence b_n = (-1)^n')
plt.xlabel('n'); plt.ylabel('b_n')
plt.show()
# 절댓값을 적용하면 |b_n| = 1 → 수렴하지 않음
# 반면 (-1)^n / n 은 절댓값은 감소하므로 0으로 수렴
c = (-1)**n / n

plt.figure()
plt.plot(n, c, 'o-', label='c_n = (-1)^n / n')
plt.axhline(0, linestyle='--', color='r', label='limit = 0')
plt.grid(True)
plt.title('Alternating sequence convergence: lim (-1)^n / n = 0')
plt.xlabel('n'); plt.ylabel('c_n')
plt.legend()
plt.show()

# %% [markdown]
# #4.미분과 변화율(Derivative & Rate of Change)
#
# - 기울기는 함수가 얼마나 빨리 변하는지를 보여줌.

# %%
import numpy as np
import matplotlib.pyplot as plt

f = lambda x: x**2
x = np.linspace(-3, 3, 400)
a = 1.0

for dx in [1.0, 0.5, 0.1, 0.01]:
    slope = (f(a+dx) - f(a)) / dx
    plt.figure()
    plt.plot(x, f(x), label='f(x)=x^2')
    plt.plot([a, a+dx], [f(a), f(a+dx)], 'r--', label=f'slope≈{slope:.2f}')
    #≈ : windows (alt+247(키패드)) / Mac: Option+x
    plt.legend(); plt.grid(True)
    plt.title(f'Secant slope (dx={dx})')
    plt.xlabel('x'); plt.ylabel('f(x)')
    plt.show()

# %%
#2단계 - 여러 점에서의 기울기
import numpy as np
import matplotlib.pyplot as plt

f = lambda x: x**2
x = np.linspace(-3, 3, 400)
points = [-2, -1, 0, 1, 2]

plt.figure()
plt.plot(x, f(x), label='f(x)=x^2')

for a in points:
    dx = 0.1
    slope = (f(a+dx) - f(a)) / dx
    tangent_x = np.linspace(a-0.8, a+0.8, 50)
    tangent_y = f(a) + slope * (tangent_x - a)
    plt.plot(tangent_x, tangent_y, '--', label=f'x={a}, slope≈{slope:.1f}')

plt.legend(); plt.grid(True)
plt.title('Tangents at different x positions')
plt.xlabel('x'); plt.ylabel('f(x)')
plt.show()

# %%
#3단계 - 수치미분 VS 해석미분
## 수치미분(Numerical differentiation): 계산으로 근사
## 해석미분(analytical differentiation): 실제 미분식 사용

import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

x = sp.Symbol('x', real=True)
f_sym = x**3 - 2*x**2 + 3*x
f_prime_sym = sp.diff(f_sym, x)

f = sp.lambdify(x, f_sym, 'numpy')
f_prime = sp.lambdify(x, f_prime_sym, 'numpy')

X = np.linspace(-2, 4, 200)
h = 1e-3
numeric_deriv = (f(X+h) - f(X-h)) / (2*h)

plt.figure()
plt.plot(X, f(X), label='f(x)')
plt.plot(X, f_prime(X), label="Analytical f'(x)")
plt.plot(X, numeric_deriv, '--', label="Numeric derivative")
plt.legend(); plt.grid(True)
plt.title('Comparison: Analytical vs Numerical Derivative')
plt.xlabel('x'); plt.ylabel('Value')
plt.show()

# %% [markdown]
# #5.행렬의 곱
# - 앞 행렬의 행(row)"와 뒤 행렬의 열(Coulmn)"을 각각 곱해 더한 것.
#
#
# $~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~C=A{\times}B$
#
# 단, A의 열수 = B의 행 수

# %%
#1단계 - 원소별 곱(Element-wise Multiplication)
## * 연산자는 같은 위치의 원소끼리 곱하는 것.
## 수학적으로는 Hadamard product 또는 Element-wise product라고 함.

import numpy as np

A = np.array([[1, 2],
              [3, 4]])
B = np.array([[10, 20],
              [30, 40]])

# Element-wise product
C = A * B
print("A =\n", A)
print("B =\n", B)
print("A * B (element-wise) =\n", C)
# Out:
# A =
#  [[1 2]
#  [3 4]]
# B =
#  [[10 20]
#  [30 40]]
# A * B (element-wise) =
#  [[ 10  40]
#  [ 90 160]]

# %%
#1단계- 행렬 곱의 기본 개념
import numpy as np

# Define two matrices
A = np.array([[1, 2],
              [3, 4]])
B = np.array([[5, 6],
              [7, 8]])

C = A @ B   # same as np.dot(A,B)
print("A=\n", A)
print("B=\n", B)
print("A @ B =\n", C)
# Out:
# A=
#  [[1 2]
#  [3 4]]
# B=
#  [[5 6]
#  [7 8]]
# A @ B =
#  [[19 22]
#  [43 50]]

# %%
#2단계 크기다 다른 행렬 곱
import numpy as np

A = np.random.randint(1, 5, (2, 3))   # 2x3 matrix
B = np.random.randint(1, 5, (3, 4))   # 3x4 matrix

print("A shape:", A.shape)
print("B shape:", B.shape)

C = A @ B
print("C shape:", C.shape)
print("A=\n", A)
print("B=\n", B)
print("C=A@B=\n", C)
# Out:
# A shape: (2, 3)
# B shape: (3, 4)
# C shape: (2, 4)
# A=
#  [[4 3 2]
#  [2 4 2]]
# B=
#  [[4 1 3 4]
#  [3 3 4 4]
#  [2 1 2 4]]
# C=A@B=
#  [[29 15 28 36]
#  [24 16 26 32]]
