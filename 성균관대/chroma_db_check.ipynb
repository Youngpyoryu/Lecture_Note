# %%
import os, getpass
os.environ["OPENAI_API_KEY"] = getpass.getpass("OPENAI_API_KEY: ")

# %%
import chromadb
client = chromadb.PersistentClient(path="./chroma_db")
print([c.name for c in client.list_collections()])
# Out:
# ['rag_chunks']

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

emb = OpenAIEmbeddings(model="text-embedding-3-small")

vs = Chroma(
    persist_directory="chroma_db",
    collection_name="rag_chunks",
    embedding_function=emb,
)

docs = vs.similarity_search_with_score("질문", k=4)
docs
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_21032\1302874808.py:6: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   vs = Chroma(
# [(Document(metadata={'chunk_id': 0, 'page': 1, 'source': 'rag_sample_document_ko.pdf'}, page_content='1\n RAG 실습용 샘플 문서 (한국어)\n이 문서는 Streamlit 기반 RAG(검색 증강 생성) 챗봇 실습에서 업로드/인덱싱/질의응답 흐름을\n테스트하기 위해 만든 예시 자료입니다.\n구성: (1) RAG 개념 요약 (2) 용어 사전 (3) 미니 사례 연구 (4) FAQ (5) 테스트용 질의 예시\n1. RAG 핵심 개념\nRAG(Retrieval-Augmented Generation)는 LLM이 답을 만들기 전에, 외부 문서에서 관련 근거를\n검색(retrieval)해 컨텍스트로 제공하는 방식입니다.\n기본 파이프라인은 보통 문서 분할 → 임베딩 생성 → 벡터DB 저장 → 질의 임베딩 → 유사도 검색 →\n(선택) 재정렬 → 요약/응답 순서로 구성됩니다.\n장점: (1) 최신/사내 문서 반영 (2) 출처 기반 답변 (3) 환각(hallucination) 감소. 단점: (1) 문서\n품질/분할에 민감 (2) 검색 실패 시 답변 품질 저하 (3) 비용/지연 증가.\n2. 용어 사전\n용어\n설명\n임베딩(Embedding)\n텍스트를 고차원 벡터로 바꾼 표현. 의미가 비슷한 문장이 벡터 공간에서 가깝게 위치하도록 학습됩니다.\n청크(Chunk)\n긴 문서를 일정 길이로 나눈 조각. 검색의 기본 단위입니다.\n벡터DB(Vector DB)\n임베딩 벡터를 저장하고, 질의 벡터와의 유사도를 계산해 가까운 항목을 빠르게 찾는 데이터베이스/인덱스입니다.\nTop-k 검색\n유사도가 높은 결과 k개를 가져오는 방식.\n재정렬(Re-ranking)\n1차 검색 결과를 더 정교한 모델(예: cross-encoder)로 다시 점수화하여 순서를 개선하는 단계.\n3'),
#   1.3967231512069702),
#  (Document(metadata={'chunk_id': 1, 'page': 1, 'source': 'rag_sample_document_ko.pdf'}, page_content="스/인덱스입니다.\nTop-k 검색\n유사도가 높은 결과 k개를 가져오는 방식.\n재정렬(Re-ranking)\n1차 검색 결과를 더 정교한 모델(예: cross-encoder)로 다시 점수화하여 순서를 개선하는 단계.\n3. 미니 사례 연구: 연구실 장비 매뉴얼\n상황: 연구실에서 CT 팬텀(phantom) 촬영을 할 때, '노이즈가 커졌다'는 문의가 자주 들어옵니다.\n\x7f\n문서 A: 팬텀 촬영 SOP(노출량, 필터, 재구성 커널, 보정 절차)\n\x7f\n문서 B: 장비 오류 코드 표(예: E-103, W-210 등)와 해결 절차\n\x7f\n문서 C: 과거 QA 리포트(월별 SNR/균일도 지표)\nRAG 챗봇이 할 일: 사용자의 질문(예: 'E-103이 떴어')을 받아, 관련 오류 코드 문단과 SOP의 해당\n단계(예: 재부팅/캘리브레이션)를 찾아 요약하고, 체크리스트 형태로 안내합니다.\n4. FAQ\nQ. 검색 결과가 엉뚱한 문단만 나와요.\nA. 청크 길이/오버랩을 조정하고, 표/목차/머리말처럼 반복되는 텍스트를 제거하세요. 재정렬 모델을\n추가하면 개선되는 경우가 많습니다.\nQ. 답변에 출처를 달고 싶어요.\nA. 검색으로 가져온 청크의 문서명·페이지·문단 ID를 함께 출력하고, 답변 문장과 근거 청크를\n매칭하세요.\nQ. 한국어 문서에서 성능이 떨어져요."),
#   1.451184630393982),
#  (Document(metadata={'source': 'rag_sample_document_ko.pdf', 'chunk_id': 2, 'page': 2}, page_content='2\nA. 한국어에 강한 임베딩 모델을 쓰고, 띄어쓰기/기호 정리를 최소한으로 하되 의미가 깨지지 않게\n전처리하세요.\n5. 테스트용 질의 예시\n1\n팬텀 촬영에서 SNR을 올리려면 어떤 파라미터를 조정해야 하나요?\n2\nE-103 오류가 발생했을 때 1차로 확인할 항목은 무엇인가요?\n3\n월별 QA 리포트에서 균일도 지표가 급격히 떨어진 달이 있나요?\n4\n재정렬(Re-ranking)이 왜 필요한가요? 간단히 설명해줘.'),
#   1.4542220830917358)]
